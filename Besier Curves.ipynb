# %%
import numpy
import matplotlib.pyplot as pyplot
from functions import besier_curve

# %%
points = numpy.array([
                        [0, 0],
                        [1, 1],
                        [2, 0],
                        [3, -3],
                        [4, 3]
                    
])

# %%
POINTS = besier_curve(points)

# %%
pyplot.figure(figsize=(9,9))
pyplot.plot(POINTS[..., 0], POINTS[..., 1])
pyplot.scatter(points[:, 0], points[:, 1], c="r")
pyplot.plot(points[:, 0], points[:, 1])
pyplot.show()
