# %%
import numpy
import matplotlib.pyplot as pyplot
from functions import besier_curve

# %%
points = numpy.array([
                        [2, 1.5],
                        [2, 2],
                        [1, 2],
                        [1, 1],
                        [2, 1],
                        [2, 0],
                        [1, 0],
                        [1, 0.5],
])

weights = numpy.array([1.0, 2.0, 3.0, -0.1, -0.1, 3.0, 2.0, 1.0])

# %%
POINTS = besier_curve(points, weights, density=100)

# %%
pyplot.figure(figsize=(9,9))
pyplot.plot(POINTS[0, ...], POINTS[1, ...])
pyplot.scatter(points[:, 0], points[:, 1], c="r")
pyplot.plot(points[:, 0], points[:, 1])
pyplot.axis("auto")
pyplot.show()
